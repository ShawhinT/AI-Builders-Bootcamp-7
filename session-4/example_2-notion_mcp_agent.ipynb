# %% [markdown]
# # Notion MCP Agent
# ## ABB #7 - Session 4
#
# Code authored by: Shaw Talebi
#
# **Resources**
# - [YouTube Video](https://youtu.be/lS33W56-NGc)

# %% [markdown]
# ### imports

# %%
from agents.mcp.server import MCPServerStdio, MCPServer
from agents import Agent, gen_trace_id, trace, ModelSettings, run_demo_loop
import os
import asyncio

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# import notion api key
notion_key = os.getenv("NOTION_API_KEY")

# %% [markdown]
# ### explore MCP server tools
#
# [Instructions](https://github.com/makenotion/notion-mcp-server?tab=readme-ov-file#installation) for creating API key

# %%
async with MCPServerStdio(
    params={
        "command": "npx",
        "args": ["-y", "@notionhq/notion-mcp-server"],
        "env": {
        "OPENAPI_MCP_HEADERS": "{\"Authorization\": \"Bearer " + notion_key + "\", \"Notion-Version\": \"2022-06-28\" }"
        }
    }
) as server:
    tool_list = await server.list_tools()

# %%
toolname_list = [tool.name for tool in tool_list]
print(toolname_list)
# Out:
# ['API-get-user', 'API-get-users', 'API-get-self', 'API-post-database-query', 'API-post-search', 'API-get-block-children', 'API-patch-block-children', 'API-retrieve-a-block', 'API-update-a-block', 'API-delete-a-block', 'API-retrieve-a-page', 'API-patch-page', 'API-post-page', 'API-create-a-database', 'API-update-a-database', 'API-retrieve-a-database', 'API-retrieve-a-page-property', 'API-retrieve-a-comment', 'API-create-a-comment']

# %%
[tool.description for tool in tool_list]
# Out:
# ['Notion | Retrieve a user',
#  'Notion | List all users',
#  "Notion | Retrieve your token's bot user",
#  'Notion | Query a database',
#  'Notion | Search by title',
#  'Notion | Retrieve block children',
#  'Notion | Append block children',
#  'Notion | Retrieve a block',
#  'Notion | Update a block',
#  'Notion | Delete a block',
#  'Notion | Retrieve a page',
#  'Notion | Update page properties',
#  'Notion | Create a page',
#  'Notion | Create a database',
#  'Notion | Update a database',
#  'Notion | Retrieve a database',
#  'Notion | Retrieve a page property item',
#  'Notion | Retrieve comments',
#  'Notion | Create comment']

# %% [markdown]
# ### create main with MCP server

# %%
async def main():
    async with MCPServerStdio(
        params={
            "command": "npx",
            "args": ["-y", "@notionhq/notion-mcp-server"],
            "env": {
            "OPENAPI_MCP_HEADERS": "{\"Authorization\": \"Bearer " + notion_key + "\", \"Notion-Version\": \"2022-06-28\" }"
            }
        }
    ) as server:
        trace_id = gen_trace_id()
        with trace(workflow_name="Notion Agent Example", trace_id=trace_id):
            print(f"View trace: https://platform.openai.com/traces/trace?trace_id={trace_id}\n")
            await run(server)

# %% [markdown]
# ### create run() with agent

# %%
with open('context/example-2/instructions.md', 'r', encoding='utf-8') as file:
    instructions = file.read()

# %%
async def run(mcp_server):
    agent = Agent(
        name="Notion Agent",
        model="gpt-4.1-2025-04-14",
        instructions=instructions,
        mcp_servers=[mcp_server],
    )
    ModelSettings.tool_choice = "required"

    await run_demo_loop(agent)

# %% [markdown]
# ### run agent
#
# [Example](https://github.com/ShawhinT/AI-Builders-Bootcamp-6/blob/main/session-4/example_2-notion-mcp-agent.ipynb) with custom CLI

# %%
await main()
# find me posts about AI consulting
# Out:
# View trace: https://platform.openai.com/traces/trace?trace_id=trace_64007d8032574141a14923225acab87a
#  >  find me posts about AI consulting
# [Agent updated: Notion Agent]
#
# [tool called]
#
# [tool output: {"type":"text","text":"{\"object\":\"list\",\"results\":[{\"object\":\"page\",\"id\":\"2915f2e2-6be9-8003-b1a0-ccfb793a4e26\",\"created_time\":\"2025-10-19T14:52:00.000Z\",\"last_edited_time\":\"2025-11-06T14:17:00.000Z\",\"created_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"last_edited_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"cover\":null,\"icon\":{\"type\":\"emoji\",\"emoji\":\"✅\"},\"parent\":{\"type\":\"database_id\",\"database_id\":\"e8ab6a81-dd97-4598-8856-ff16c0d1eb78\"},\"archived\":false,\"in_trash\":false,\"is_locked\":false,\"properties\":{\"Time\":{\"id\":\"%3A%3Ed%5B\",\"type\":\"rich_text\",\"rich_text\":[]},\"Media\":{\"id\":\"%3CS%5D%60\",\"type\":\"files\",\"files\":[]},\"Date\":{\"id\":\"%60JaL\",\"type\":\"date\",\"date\":{\"start\":\"2025-11-06\",\"end\":null,\"time_zone\":null}},\"Copy\":{\"id\":\"%60KJ%5D\",\"type\":\"rich_text\",\"rich_text\":[]},\"Channel\":{\"id\":\"~aEy\",\"type\":\"multi_select\",\"multi_select\":[]},\"Name\":{\"id\":\"title\",\"type\":\"title\",\"title\":[{\"type\":\"text\",\"text\":{\"content\":\"What AI Coding is (Actually) About\",\"link\":null},\"annotations\":{\"bold\":true,\"italic\":false,\"strikethrough\":false,\"underline\":false,\"code\":false,\"color\":\"default\"},\"plain_text\":\"What AI Coding is (Actually) About\",\"href\":null}]}},\"url\":\"https://www.notion.so/What-AI-Coding-is-Actually-About-2915f2e26be98003b1a0ccfb793a4e26\",\"public_url\":null},{\"object\":\"page\",\"id\":\"2915f2e2-6be9-8059-8a37-fe3ee8d405d6\",\"created_time\":\"2025-10-19T14:37:00.000Z\",\"last_edited_time\":\"2025-10-22T18:23:00.000Z\",\"created_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"last_edited_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"cover\":null,\"icon\":{\"type\":\"emoji\",\"emoji\":\"✅\"},\"parent\":{\"type\":\"database_id\",\"database_id\":\"e8ab6a81-dd97-4598-8856-ff16c0d1eb78\"},\"archived\":false,\"in_trash\":false,\"is_locked\":false,\"properties\":{\"Time\":{\"id\":\"%3A%3Ed%5B\",\"type\":\"rich_text\",\"rich_text\":[]},\"Media\":{\"id\":\"%3CS%5D%60\",\"type\":\"files\",\"files\":[]},\"Date\":{\"id\":\"%60JaL\",\"type\":\"date\",\"date\":{\"start\":\"2025-10-22\",\"end\":null,\"time_zone\":null}},\"Copy\":{\"id\":\"%60KJ%5D\",\"type\":\"rich_text\",\"rich_text\":[]},\"Channel\":{\"id\":\"~aEy\",\"type\":\"multi_select\",\"multi_select\":[]},\"Name\":{\"id\":\"title\",\"type\":\"title\",\"title\":[{\"type\":\"text\",\"text\":{\"content\":\"Data Science for AI Engineers\",\"link\":null},\"annotations\":{\"bold\":false,\"italic\":false,\"strikethrough\":false,\"underline\":false,\"code\":false,\"color\":\"default\"},\"plain_text\":\"Data Science for AI Engineers\",\"href\":null}]}},\"url\":\"https://www.notion.so/Data-Science-for-AI-Engineers-2915f2e26be980598a37fe3ee8d405d6\",\"public_url\":null},{\"object\":\"page\",\"id\":\"27c5f2e2-6be9-8036-a6a9-e68fc9c5b02e\",\"created_time\":\"2025-09-28T17:44:00.000Z\",\"last_edited_time\":\"2025-10-16T14:41:00.000Z\",\"created_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"last_edited_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"cover\":null,\"icon\":{\"type\":\"emoji\",\"emoji\":\"✅\"},\"parent\":{\"type\":\"database_id\",\"database_id\":\"e8ab6a81-dd97-4598-8856-ff16c0d1eb78\"},\"archived\":false,\"in_trash\":false,\"is_locked\":false,\"properties\":{\"Time\":{\"id\":\"%3A%3Ed%5B\",\"type\":\"rich_text\",\"rich_text\":[]},\"Media\":{\"id\":\"%3CS%5D%60\",\"type\":\"files\",\"files\":[]},\"Date\":{\"id\":\"%60JaL\",\"type\":\"date\",\"date\":{\"start\":\"2025-10-16\",\"end\":null,\"time_zone\":null}},\"Copy\":{\"id\":\"%60KJ%5D\",\"type\":\"rich_text\",\"rich_text\":[]},\"Channel\":{\"id\":\"~aEy\",\"type\":\"multi_select\",\"multi_select\":[]},\"Name\":{\"id\":\"title\",\"type\":\"title\",\"title\":[{\"type\":\"text\",\"tex ...
# Here are some posts in your notes database related to AI consulting:
#
# 1. **What AI Coding is (Actually) About**
#    - Last edited: Nov 6, 2025
#    - [Link to Notion page](https://www.notion.so/What-AI-Coding-is-Actually-About-2915f2e26be98003b1a0ccfb793a4e26)
#
# 2. **Data Science for AI Engineers**
#    - Last edited: Oct 22, 2025
#    - [Link to Notion page](https://www.notion.so/Data-Science-for-AI-Engineers-2915f2e26be980598a37fe3ee8d405d6)
#
# 3. **Ship AI 4**
#    - Last edited: Oct 16, 2025
#    - [Link to Notion page](https://www.notion.so/Ship-AI-4-27c5f2e26be98036a6a9e68fc9c5b02e)
#
# 4. **Ship AI 3**
#    - Last edited: Oct 14, 2025
#    - [Link to Notion page](https://www.notion.so/Ship-AI-3-27c5f2e26be980f49478c0f2ac6fa315)
#
# 5. **Speak AI 5**
#    - Last edited: Oct 13, 2025
#    - [Link to Notion page](https://www.notion.so/Speak-AI-5-27c5f2e26be980e483e4d72bb6ed9a26)
#
# 6. **Speak AI 4**
#    - Last edited: Oct 12, 2025
#    - [Link to Notion page](https://www.notion.so/Speak-AI-4-27c5f2e26be9803d889bf50e226c206f)
#
# 7. **Speak AI 3**
#    - Last edited: Oct 11, 2025
#    - [Link to Notion page](https://www.notion.so/Speak-AI-3-27c5f2e26be98011bef5fca3d7874315)
#
# 8. **Speak AI 2**
#    - Last edited: Oct 10, 2025
#    - [Link to Notion page](https://www.notion.so/Speak-AI-2-27c5f2e26be9803fbbcada8ad4adf17f)
#
# Do you want to review the content or generate a new post based on one of these? If so, let me know which one you'd like to use.
#  >  Write me a new post like these here
# [Agent updated: Notion Agent]
#
# [tool called]
#
# [tool output: {"type":"text","text":"{\"object\":\"list\",\"results\":[{\"object\":\"block\",\"id\":\"2915f2e2-6be9-80cc-a690-f2dd7ba4cdde\",\"parent\":{\"type\":\"page_id\",\"page_id\":\"2915f2e2-6be9-8003-b1a0-ccfb793a4e26\"},\"created_time\":\"2025-10-19T14:52:00.000Z\",\"last_edited_time\":\"2025-11-06T14:15:00.000Z\",\"created_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"last_edited_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"has_children\":false,\"archived\":false,\"in_trash\":false,\"type\":\"heading_1\",\"heading_1\":{\"rich_text\":[],\"is_toggleable\":false,\"color\":\"default\"}},{\"object\":\"block\",\"id\":\"2a35f2e2-6be9-80fd-b181-e7737f11f719\",\"parent\":{\"type\":\"page_id\",\"page_id\":\"2915f2e2-6be9-8003-b1a0-ccfb793a4e26\"},\"created_time\":\"2025-11-06T14:15:00.000Z\",\"last_edited_time\":\"2025-11-06T14:15:00.000Z\",\"created_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"last_edited_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"has_children\":false,\"archived\":false,\"in_trash\":false,\"type\":\"paragraph\",\"paragraph\":{\"rich_text\":[{\"type\":\"text\",\"text\":{\"content\":\"What AI coding is (actually) about.\",\"link\":null},\"annotations\":{\"bold\":false,\"italic\":false,\"strikethrough\":false,\"underline\":false,\"code\":false,\"color\":\"default\"},\"plain_text\":\"What AI coding is (actually) about.\",\"href\":null}],\"color\":\"default\"}},{\"object\":\"block\",\"id\":\"2a35f2e2-6be9-80dc-b082-e20b847c2c9c\",\"parent\":{\"type\":\"page_id\",\"page_id\":\"2915f2e2-6be9-8003-b1a0-ccfb793a4e26\"},\"created_time\":\"2025-11-06T14:15:00.000Z\",\"last_edited_time\":\"2025-11-06T14:15:00.000Z\",\"created_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"last_edited_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"has_children\":false,\"archived\":false,\"in_trash\":false,\"type\":\"paragraph\",\"paragraph\":{\"rich_text\":[{\"type\":\"text\",\"text\":{\"content\":\"The reason an AI can't code your entire app is that you're not just outsourcing the coding part...\",\"link\":null},\"annotations\":{\"bold\":false,\"italic\":false,\"strikethrough\":false,\"underline\":false,\"code\":false,\"color\":\"default\"},\"plain_text\":\"The reason an AI can't code your entire app is that you're not just outsourcing the coding part...\",\"href\":null}],\"color\":\"default\"}},{\"object\":\"block\",\"id\":\"2a35f2e2-6be9-80b1-b328-ee5e07910b61\",\"parent\":{\"type\":\"page_id\",\"page_id\":\"2915f2e2-6be9-8003-b1a0-ccfb793a4e26\"},\"created_time\":\"2025-11-06T14:15:00.000Z\",\"last_edited_time\":\"2025-11-06T14:15:00.000Z\",\"created_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"last_edited_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"has_children\":false,\"archived\":false,\"in_trash\":false,\"type\":\"paragraph\",\"paragraph\":{\"rich_text\":[{\"type\":\"text\",\"text\":{\"content\":\"you're also outsourcing the thinking part of the development process.\",\"link\":null},\"annotations\":{\"bold\":false,\"italic\":false,\"strikethrough\":false,\"underline\":false,\"code\":false,\"color\":\"default\"},\"plain_text\":\"you're also outsourcing the thinking part of the development process.\",\"href\":null}],\"color\":\"default\"}},{\"object\":\"block\",\"id\":\"2a35f2e2-6be9-8077-9223-f5c8df6f09a1\",\"parent\":{\"type\":\"page_id\",\"page_id\":\"2915f2e2-6be9-8003-b1a0-ccfb793a4e26\"},\"created_time\":\"2025-11-06T14:15:00.000Z\",\"last_edited_time\":\"2025-11-06T14:15:00.000Z\",\"created_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"last_edited_by\":{\"object\":\"user\",\"id\":\"77b0e182-89f3-44c4-be6d-4a3815f100c1\"},\"has_children\":false,\"archived\":false,\"in_trash\":false,\"type\":\"paragraph\",\"paragraph\":{\"rich_text\":[{\"type\":\"te ...
# Step 1: Purpose & Audience
# - Purpose: Educate readers on a fundamental reality of AI consulting and development.
# - Audience: Aspiring AI consultants, engineers, and founders interested in practical AI application development.
#
# Step 2: Wireframe
#
# [Hook introducing a misconception about AI consulting/coding]
# [Breakdown: Why AI isn’t “just coding” and the real value an AI consultant provides—emphasize the thinking/framework/mental models, not just code output]
# [Actionable insight: Key practice for effective AI consulting/coding with LLMs]
# [CTA: Ask readers for their approach or workflow]
#
# Step 3: Write the Meat
#
# A common misconception in AI consulting: that an AI model can replace the need for your own strategic thinking and problem definition. Most clients think they’re paying for code, but the reality is they’re investing in your ability to translate a fuzzy goal into a clear, actionable workflow.
#
# If you hand off “the whole thing” to a model, you also hand off the core responsibilities that make consulting valuable—understanding requirements, clarifying unknowns, and iteratively defining success.
#
# The key practice? Maintain a tight loop between your mental model and the AI’s outputs. Actively specify, probe, and evaluate what it produces. Don’t outsource the thinking. Use the LLM as an amplifier, not as a replacement.
#
# Step 4: CTA
#
# What’s your strategy for keeping control of the “thinking” in AI projects?
#
# Step 5: Hook Directions
#
# - [Misconception/clarity] “AI consulting isn’t about writing code.”
# - [Problem/solution] “If you outsource decision-making to an LLM, you’ll lose the real value.”
# - [Beginner-to-expert] “Most new consultants get this wrong about AI projects…”
# - [User’s phrasing] “What AI coding is (actually) about.”
# - [Results] “Why AI can’t build your entire app for you (even if it writes code).”
#
# Step 6: Pick the Best Hook
#
# Based on these, the clearest and most curiosity-driven option that fits Shaw’s style is:
# “AI consulting isn’t about writing code.”
#
# Step 7: Draft the Full Post
#
# AI consulting isn’t about writing code.
#
# The biggest misconception I see (from clients and new consultants alike) is that an AI system can just “do the work” if you throw a spec at it.
#
# But most of the real value in AI consulting comes before the code:
# - Clarifying requirements that are often fuzzy
# - Designing workflows that solve end-user problems
# - Iteratively evaluating what AI produces so you don’t lose context when issues arise
#
# If you try to outsource the thinking and problem definition, you’ll end up with a black box you can’t maintain.
#
# My process:
# Keep a tight loop between what you expect and what the model gives you back. Always specify, question, and test outputs so you actually understand what’s happening. That’s where real consulting value comes from—connecting the technical work to business results.
#
# What’s your strategy for keeping control of the “thinking” in AI projects?
#
# Step 8: Final Edits & Audits
#
# - Only one em dash, justified for clarity: “…That’s where real consulting value comes from—connecting the technical work to business results.”
# - No business clichés, motivational hype, or idioms.
# - CTA is focused and practical.
# - Scannable format, bullet points, expert yet approachable tone.
# - Structure and style match Shaw’s voice and prior examples.
# - Literal, direct, educational throughout.
#
# # Final Post
#
# AI consulting isn’t about writing code.
#
# The biggest misconception I see (from clients and new consultants alike) is that an AI system can just “do the work” if you throw a spec at it.
#
# But most of the real value in AI consulting comes before the code:
# - Clarifying requirements that are often fuzzy
# - Designing workflows that solve end-user problems
# - Iteratively evaluating what AI produces so you don’t lose context when issues arise
#
# If you try to outsource the thinking and problem definition, you’ll end up with a black box you can’t maintain.
#
# My process:
# Keep a tight loop between what you expect and what the model gives you back. Always specify, question, and test outputs so you actually understand what’s happening. That’s where real consulting value comes from—connecting the technical work to business results.
#
# What’s your strategy for keeping control of the “thinking” in AI projects?
#  >  exit

# %%
# # to run in a .py script use
# if __name__ == "__main__":
#     asyncio.run(main())
